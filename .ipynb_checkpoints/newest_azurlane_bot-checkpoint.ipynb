# %%
import pyautogui as gui
import time
import cv2
from PIL import Image
import pandas as pd
import numpy as np
import os
import glob
import util_gui
import re

# %%
df_image.index
# Out:
# Index(['OpS_battle.png', 'OpS_collect_ops.png', 'OpS_friend.png',
#        'OpS_guild.png', 'OpS_helena_meta.png',
#        'OpS_info_analysis_renown_meta.png', 'OpS_renown_meta.png',
#        'OpS_request_support.png', 'OpS_start_battle.png', 'OpS_world.png',
#        'PVP_gen.png', 'Retire_confirm.png', 'Retire_confirm_disassemble.png',
#        'Retire_confirm_elite.png', 'Retire_disassemble.png',
#        'Retire_elite.png', 'Retire_no_retire.png', 'Retire_quick_retire.png',
#        'Retire_return.png', 'Retire_sort.png', 'Retire_tap.png',
#        'Stage_12_2_hard.png', 'Stage_affinity.png', 'Stage_auto_search.png',
#        'Stage_continue.png', 'Stage_stage1.png', 'Stage_stage_2.png'],
#       dtype='object')

# %%
#Creating/Resetting the Image DataFrame
a = input('???????????????????')
if a:
    lista_path_imagens = [i for i in glob.iglob(os.path.join(os.getcwd(),r"Images\**\*.png"))]
    lista_variable_names = list(map(lambda x:os.path.split(os.path.dirname(x))[-1]+"_"+os.path.basename(x),lista_path_imagens))
    df_image = pd.DataFrame(index = lista_variable_names,columns = ['Path','Category','Region'])
    df_image['Path'] = lista_path_imagens
    df_image['Category'] = list(map(lambda x: os.path.split(os.path.dirname(x))[-1],lista_path_imagens))
    df_image.to_csv(os.path.join(os.getcwd(),r"CSVs\data_images.csv"))
# Out:
# ???????????????????s

# %%
#Updating df_image
lista_path_imagens = [i for i in glob.iglob(os.path.join(os.getcwd(),r"Images\**\*.png"))]
lista_variable_names = list(map(lambda x:os.path.split(os.path.dirname(x))[-1]+"_"+os.path.basename(x),lista_path_imagens))
#Adding new row
df_image = pd.read_csv(os.path.join(os.getcwd(),r"CSVs\data_images.csv"),index_col = 'Unnamed: 0')
for i,name in enumerate(lista_variable_names): 
    if name not in df_image.index:
        print(f'Adding new row: {name}')
        df_image.loc[name] = df_image.iloc[0]*0
        df_image.loc[name,'Path'] = lista_path_imagens[i]
        df_image.loc[name,'Category'] = os.path.split(os.path.dirname(lista_path_imagens[i]))[-1]
#Deleting existing row
for name in df_image.index:
    if name not in lista_variable_names:
        print(f'Dropping row: {name}')
        df_image.drop(index=name,inplace=True)
df_image.to_csv(os.path.join(os.getcwd(),r"CSVs\data_images.csv"))
# Out:
# Dropping row: PVP_exercise_pvp - Copia.png

# %%
df_image = pd.read_csv(os.path.join(os.getcwd(),r"CSVs\data_images.csv"),index_col = 'Unnamed: 0')

# %%
#Dicionario de df_time > para quando for ter de usar para stages diferentes, com df_time diferentes
dict_df_time = {} 

#Gerar o time_XX.csv

re_stage = 'Stage_stage.*\.png' #Regex para achar o nome dos Stages, dentro da pasta Stage
#Procura matches com re_stage no index da df quando df['Category'] == 'Stage'
#Os matches sao colocados em uma lista e extraidos quando o match for diferente de None
#Obs: re.search retorna MatchObject se der match, None se nao der match
#Dos MatchObject, sao extraidos o .group(), que retorna a parte da string que deu match (do ponto do match até o final da string)
lista_stages = [x.group() for x in list(map(lambda x: re.search(re_stage,x),df_image[df_image['Category'] == 'Stage'].index)) if x != None]
lista_csvs = glob.glob(os.path.join(os.getcwd(),r"CSVs\time_"+"*.csv"))

#Mostra as Stages para o usuario, e pede o input da Stage selecionada
print("Available Stages: ")
for i in lista_stages:
    print(i[6:-4])
stage_chosen = input("Choose the Stage to be run: ")

#Se houver um csv_time para essa stage: Le-se o csv para um df dentro do dict_df_time na chave stage_chosen
#Se nao: Cria-se um df novo e o insere no dict_df_time na chave stage_chosen
if('time_'+stage_chosen in lista_csvs):
    dict_df_time[stage_chosen] = pd.read_csv(os.path.join(os.getcwd(),rf"CSVs\{stage_chosen}.csv"),index_col = "Unnamed: 0")
else:
    dict_df_time[stage_chosen] = pd.DataFrame(columns = ["Time"])
# Out:
# Available Stages:
# stage1
# stage_2
# Choose the Stage to be run: stage2

# %%
df_image
# Out:
#                                                                                Image  \
# OpS_battle.png                     <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_collect_ops.png                <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_friend.png                     <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_guild.png                      <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_helena_meta.png                <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_info_analysis_renown_meta.png  <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_renown_meta.png                <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_request_support.png            <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_start_battle.png               <PIL.PngImagePlugin.PngImageFile image mode=RG...
# OpS_world.png                      <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_0_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_0_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_1_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_1_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_2_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_2_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_3_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_3_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_4_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_4_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_5_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_5_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_6_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_6_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_7_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_7_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_8_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_8_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_9_1.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_9_2.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# PVP_gen.png                        <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_confirm.png                 <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_confirm_disassemble.png     <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_confirm_elite.png           <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_disassemble.png             <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_elite.png                   <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_no_retire.png               <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_quick_retire.png            <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_return.png                  <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_sort.png                    <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Retire_tap.png                     <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Stage_12_2_hard.png                <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Stage_affinity.png                 <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Stage_auto_search.png              <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Stage_continue.png                 <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Stage_stage1.png                   <PIL.PngImagePlugin.PngImageFile image mode=RG...
# Stage_stage_2.png                  <PIL.PngImagePlugin.PngImageFile image mode=RG...
#
#                                                                                 Path  \
# OpS_battle.png                     C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_collect_ops.png                C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_friend.png                     C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_guild.png                      C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_helena_meta.png                C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_info_analysis_renown_meta.png  C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_renown_meta.png                C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_request_support.png            C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_start_battle.png               C:\Users\EricR\Documents\python\azurlane\Image...
# OpS_world.png                      C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_0_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_0_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_1_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_1_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_2_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_2_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_3_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_3_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_4_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_4_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_5_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_5_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_6_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_6_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_7_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_7_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_8_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_8_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_9_1.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_9_2.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# PVP_gen.png                        C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_confirm.png                 C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_confirm_disassemble.png     C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_confirm_elite.png           C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_disassemble.png             C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_elite.png                   C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_no_retire.png               C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_quick_retire.png            C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_return.png                  C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_sort.png                    C:\Users\EricR\Documents\python\azurlane\Image...
# Retire_tap.png                     C:\Users\EricR\Documents\python\azurlane\Image...
# Stage_12_2_hard.png                C:\Users\EricR\Documents\python\azurlane\Image...
# Stage_affinity.png                 C:\Users\EricR\Documents\python\azurlane\Image...
# Stage_auto_search.png              C:\Users\EricR\Documents\python\azurlane\Image...
# Stage_continue.png                 C:\Users\EricR\Documents\python\azurlane\Image...
# Stage_stage1.png                   C:\Users\EricR\Documents\python\azurlane\Image...
# Stage_stage_2.png                  C:\Users\EricR\Documents\python\azurlane\Image...
#
#                                   Category Region
# OpS_battle.png                         OpS    NaN
# OpS_collect_ops.png                    OpS    NaN
# OpS_friend.png                         OpS    NaN
# OpS_guild.png                          OpS    NaN
# OpS_helena_meta.png                    OpS    NaN
# OpS_info_analysis_renown_meta.png      OpS    NaN
# OpS_renown_meta.png                    OpS    NaN
# OpS_request_support.png                OpS    NaN
# OpS_start_battle.png                   OpS    NaN
# OpS_world.png                          OpS    NaN
# PVP_0_1.png                            PVP    NaN
# PVP_0_2.png                            PVP    NaN
# PVP_1_1.png                            PVP    NaN
# PVP_1_2.png                            PVP    NaN
# PVP_2_1.png                            PVP    NaN
# PVP_2_2.png                            PVP    NaN
# PVP_3_1.png                            PVP    NaN
# PVP_3_2.png                            PVP    NaN
# PVP_4_1.png                            PVP    NaN
# PVP_4_2.png                            PVP    NaN
# PVP_5_1.png                            PVP    NaN
# PVP_5_2.png                            PVP    NaN
# PVP_6_1.png                            PVP    NaN
# PVP_6_2.png                            PVP    NaN
# PVP_7_1.png                            PVP    NaN
# PVP_7_2.png                            PVP    NaN
# PVP_8_1.png                            PVP    NaN
# PVP_8_2.png                            PVP    NaN
# PVP_9_1.png                            PVP    NaN
# PVP_9_2.png                            PVP    NaN
# PVP_gen.png                            PVP    NaN
# Retire_confirm.png                  Retire    NaN
# Retire_confirm_disassemble.png      Retire    NaN
# Retire_confirm_elite.png            Retire    NaN
# Retire_disassemble.png              Retire    NaN
# Retire_elite.png                    Retire    NaN
# Retire_no_retire.png                Retire    NaN
# Retire_quick_retire.png             Retire    NaN
# Retire_return.png                   Retire    NaN
# Retire_sort.png                     Retire    NaN
# Retire_tap.png                      Retire    NaN
# Stage_12_2_hard.png                  Stage    NaN
# Stage_affinity.png                   Stage    NaN
# Stage_auto_search.png                Stage    NaN
# Stage_continue.png                   Stage    NaN
# Stage_stage1.png                     Stage    NaN
# Stage_stage_2.png                    Stage    NaN

# %%
#Appending time values to current "df_time"
dict_df_time[stage_chosen].loc[len(dict_df_time[stage_chosen].index)] = time.time() - contador

# %%
#Updating the time_XX.csv
df_time.to_csv(os.path.join(os.getcwd(),fr"CSVs\time_{stage}.csv"))
